# %%
import pandas as pd
import re

# %%
df = pd.read_csv('dataset/final_Dataset.csv')
df
# Out:
#                                            job_title  \
# 0                                       Admin Proyek
# 1                                         Staff HRGA
# 2      Human resources manager ( mandarin speaking )
# 3                              Staff Admin Penagihan
# 4                                   Administrator HR
# ...                                              ...
# 17819                           Staff Gudang & Kurir
# 17820                                 Staff Shipping
# 17821                                         Driver
# 17822                                   Admin Gudang
# 17823                             Driver operasional
#
#                            company_name              location   job_type  \
# 0                 PT Visi Maine Perkasa                 Tebet  FULL_TIME
# 1                        Rosalyne Group  Kemantren Mergangsan  FULL_TIME
# 2      PT.WESTERFIELD ALUMINA INDONESIA                  Toba  FULL_TIME
# ...

# %%
df['job_responsibilities']
# Out:
# 0        Deskripsi pekerjaan Admin Proyek PT Visi Maine...
# 1        Deskripsi pekerjaan Staff HRGA Rosalyne Group ...
# 2        Deskripsi pekerjaan Human resources manager ( ...
# 3        Deskripsi pekerjaan Staff Admin Penagihan PT. ...
# 4        Deskripsi pekerjaan Administrator HR PT Hasta ...
#                                ...
# 17819    Deskripsi pekerjaan Staff Gudang & Kurir Pt Em...
# 17820    Deskripsi pekerjaan Staff Shipping Suksesindo ...
# 17821    Deskripsi pekerjaan Driver The Clinic Beautylo...
# 17822    Deskripsi pekerjaan Admin Gudang Cherry Auto C...
# 17823    Deskripsi pekerjaan Driver operasional CV Cuci...
# Name: job_responsibilities, Length: 17824, dtype: str
